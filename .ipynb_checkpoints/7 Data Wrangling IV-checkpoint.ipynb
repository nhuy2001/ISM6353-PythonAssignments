# %%
# import pandas
import pandas as pd

# %% [markdown]
# ## Concatenation
#
# Concatenation combines DataFrames using **pd.concat**. The number of rows or columns should match among dataframes to be combined.

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index = [0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index = [0, 1, 2, 3])

df3 = pd.DataFrame({'E': ['A8', 'A9', 'A10', 'A11'],
                    'F': ['B8', 'B9', 'B10', 'B11'],
                    'G': ['C8', 'C9', 'C10', 'C11'],
                    'H': ['D8', 'D9', 'D10', 'D11']},
                    index = [0, 1, 2, 3])

df4 = pd.DataFrame({'A': ['A8', 'A9', 'A10'],
                    'B': ['B8', 'B9', 'B10'],
                    'C': ['C8', 'C9', 'C10']},
                    index = [0, 1, 2])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
df3
# Out:
#      E    F    G    H
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
df4
# Out:
#      A    B    C
# 0   A8   B8   C8
# 1   A9   B9   C9
# 2  A10  B10  C10

# %%
pd.concat([df1, df2, df3])
# Out:
#      A    B    C    D    E    F    G    H
# 0   A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2  NaN  NaN  NaN  NaN
# 3   A3   B3   C3   D3  NaN  NaN  NaN  NaN
# 0   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 1   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 2   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 3   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 1  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 2  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 3  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
pd.concat([df1, df2, df3], axis = 1)
# Out:
#     A   B   C   D   A   B   C   D    E    F    G    H
# 0  A0  B0  C0  D0  A4  B4  C4  D4   A8   B8   C8   D8
# 1  A1  B1  C1  D1  A5  B5  C5  D5   A9   B9   C9   D9
# 2  A2  B2  C2  D2  A6  B6  C6  D6  A10  B10  C10  D10
# 3  A3  B3  C3  D3  A7  B7  C7  D7  A11  B11  C11  D11

# %% [markdown]
# ## Append
#
# Append is a specific case of concat (axis=0, join='outer')

# %%
df1.append(df2)
# Out:
# C:\Users\andyc\AppData\Local\Temp\ipykernel_25052\2995832154.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2)
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
pd.concat([df1, df2])
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %% [markdown]
# ## Merge
#
# Merge dataframes using **merge** (similar to joins in SQL).

# %%
t1 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
t2 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4'],
                          'C': ['C0', 'C1', 'C2', 'C3', 'C4'],
                          'D': ['D0', 'D1', 'D2', 'D3', 'D4']})

# %%
t1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
t2
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3
# 4  K4  C4  D4

# %%
t1.merge(t2, how = 'inner', on = 'key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
t1.merge(t2, how = 'left', on = 'key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
t1.merge(t2, how = 'right', on = 'key')
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1   A1   B1  C1  D1
# 2  K2   A2   B2  C2  D2
# 3  K3   A3   B3  C3  D3
# 4  K4  NaN  NaN  C4  D4
